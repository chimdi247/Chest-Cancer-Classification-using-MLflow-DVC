# %%
d = {"key":"value","key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %% [markdown]
# ### Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/12Cb9KaSMHz3l-jhfxR4rflaWeVK28l_u/view?usp=drive_link"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '12Cb9KaSMHz3l-jhfxR4rflaWeVK28l_u'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=12Cb9KaSMHz3l-jhfxR4rflaWeVK28l_u
# From (redirected): https://drive.google.com/uc?id=12Cb9KaSMHz3l-jhfxR4rflaWeVK28l_u&confirm=t&uuid=5522068a-7e18-413c-bdb4-2509482f0cec
# To: c:\Users\chimd\OneDrive\Desktop\MLops and LLMops\Chest-Cancer-Classification-using-MLflow-DVC\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:08<00:00, 5.62MB/s]
# 'Chest-CT-Scan-data.zip'
